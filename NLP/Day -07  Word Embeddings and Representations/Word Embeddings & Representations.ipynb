# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Word Embedding and Representation</h2>
#
# ---
# ```text
# 🔹 What is Word Representation?
# 🔹 What are Word Embeddings?
# 🔹 Why Do We Need Word Embeddings?
# 🔹 Traditional Approaches vs. Word Embeddings
# 🔹 How Do Word Embeddings Work?
# 🔹 Types of Word Embeddings
# 🔹 Visualizing Word Embeddings

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">What is Word Embedding?</h2>
#
#
# ---
#
# 👉কম্পিউটার মানুষের ভাষা বোঝে না, সে শুধু সংখ্যা বোঝে। ওয়ার্ড এম্বেডিং শব্দগুলোকে সংখ্যায় রূপান্তর করে, যাতে কম্পিউটার সেগুলো বুঝতে পারে। ওয়ার্ড এম্বেডিং হলো ওয়ার্ড রিপ্রেজেন্টেশনের একটি প্রকার।
#
# ---
#
# ### **১. What is Word Embedding?**
# 👉ওয়ার্ড এম্বেডিং হলো **শব্দকে সংখ্যা বা ভেক্টরের (Vector) মাধ্যমে উপস্থাপন করার একটি কৌশল**।
# এই ভেক্টরগুলো এমনভাবে তৈরি করা হয় যাতে কাছাকাছি অর্থের শব্দগুলোর ভেক্টরও কাছাকাছি থাকে।
#
# 📌 **Example:**
# - **"রাজা" এবং "রানী" শব্দগুলোর ভেক্টর "মানুষ" এবং "মহিলা" শব্দগুলোর ভেক্টরের কাছাকাছি থাকবে।**
#
# ```plaintext
# King   = [0.9, 0.3, 0.7, 0.5]
# Queen  = [0.9, 0.4, 0.7, 0.5]
# Apple  = [0.2, 0.7, 0.8, 0.6]

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Word Embedding</h2>
#
#
# ### **2.  Why is Word Embedding necessary?**
# - ✅ কম্পিউটার মানুষের ভাষা বোঝে না, সে শুধু সংখ্যা বোঝে।
# - ✅ ওয়ার্ড এম্বেডিং শব্দগুলোকে সংখ্যায় রূপান্তর করে, যাতে কম্পিউটার সেগুলো বুঝতে পারে।
# - ✅ এটি শব্দগুলোর মধ্যে সম্পর্ক বুঝতে সাহায্য করে, যা বিভিন্ন NLP কাজে (যেমন, Machine translation, text classification) গুরুত্বপূর্ণ।
#
# ### **৩. How does Word Embedding work?**
# - ওয়ার্ড এম্বেডিং তৈরি করার জন্য বিভিন্ন অ্যালগরিদম ব্যবহার করা হয়, যেমন Word2Vec, GloVe, and FastText।
# - এই অ্যালগরিদমগুলো একটি বিশাল text dataset analysis করে এবং শব্দগুলোর মধ্যে pattern খুঁজে বের করে।
# - তারপর, প্রতিটি শব্দের জন্য একটি ভেক্টর তৈরি করা হয়, যা সেই শব্দের অর্থ এবং অন্যান্য শব্দের সাথে সম্পর্ক প্রকাশ করে।
#
# ### **৪. What kind of Word Embedding?**
# ⭐  Static Word Embedding:
# - ✅ প্রতিটি শব্দের জন্য একটি নির্দিষ্ট ভেক্টর তৈরি করা হয়, যা পরিবর্তন হয় না।
# - ✅ উদাহরণ: Word2Vec, GloVe
#
# ⭐  Contextual Word Embedding:
# - ✅ একটি শব্দের ভেক্টর তার আশেপাশের শব্দের উপর নির্ভর করে পরিবর্তিত হয়।
# - ✅ উদাহরণ: BERT, ELMo
#
# ### **5. Example**
# ধরুন, "বিড়ালটি কালো রঙের"।
# - ওয়ার্ড এম্বেডিং এর মাধ্যমে, "বিড়ালটি", "কালো", এবং "রঙের" শব্দগুলোর জন্য ভেক্টর তৈরি করা হবে।
# - এই ভেক্টরগুলো এমনভাবে তৈরি করা হবে যাতে "বিড়ালটি" এবং "কুকুরটি" শব্দগুলোর ভেক্টর কাছাকাছি থাকে।
# - এই ভেক্টরগুলো ব্যবহার করে Machine বাক্যটির অর্থ বুঝতে পারবে।

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Word Representation</h2>
#
# ---
#
# ### **৫. Word Representation**
# 👉 ওয়ার্ড রিপ্রেজেন্টেশন হলো কোনো শব্দকে সংখ্যার (ভেক্টর) মাধ্যমে প্রকাশ করার একটি পদ্ধতি, যাতে কম্পিউটার সেই শব্দের অর্থ ও সম্পর্ক বুঝতে পারে।
# 🎯 পদ্ধতি:
# - 🔹Bag of Words (BoW) → শব্দগুলোর উপস্থিতি গণনা করে।
# - 🔹TF-IDF (Term Frequency-Inverse Document Frequency) → গুরুত্বপূর্ণ শব্দগুলোর ওজন নির্ধারণ করে।
# - 🔹One-Hot Encoding → প্রতিটি শব্দকে 0 এবং 1 এর ম্যাট্রিক্সে রূপান্তরিত করে।
#
# ⭐ Bag of Words (BoW)
# - Solutions:
# - Sentence 1: "আমি ফুটবল ভালোবাসি।"
# - Sentence 2: "আমি ক্রিকেট খেলতে পছন্দ করি।"
# - Sentence 3: "সে ফুটবল খেলতে ভালোবাসে।"
#
# 📌 Step 1: সব ইউনিক শব্দ বের করা
# ['আমি', 'ফুটবল', 'ভালোবাসি', 'ক্রিকেট', 'খেলতে', 'পছন্দ', 'করি', 'সে', 'ভালোবাসে']
#
# 📌 Step 2: শব্দগুলোর উপস্থিতি গণনা করে ম্যাট্রিক্স তৈরি করা
# # ![image.png](attachment:4a1ba8f9-954a-4064-8122-dd07aa632650.png)
#
#
# #### 🔹 ২. TF-IDF (Term Frequency - Inverse Document Frequency)
# 💡 কনসেপ্ট:
# 👉 TF-IDF হলো BoW-এর একটি উন্নত সংস্করণ, যা শুধু শব্দগুলোর উপস্থিতি গণনা করে না, বরং তাদের
# 👉 তাই TF-IDF শব্দগুলোর ওজন নির্ধারণ করে, যাতে গুরুত্বপূর্ণ শব্দগুলো বেশি প্রাধান্য পায়।
#
# 🎯 TF-IDF-এর মূল লক্ষ্য:
# - কোন শব্দ বেশি ব্যবহৃত হয় তা নির্ধারণ করা (TF - Term Frequency)
# - কোন শব্দ কমন নয় এবং গুরুত্বপূর্ণ (IDF - Inverse Document Frequency)
#
#
# ## **📌 How TF-IDF works?**
#
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Step 1: Calculating Term Frequency (TF)</h2>
#
#   <p style="text-align: center; font-size: 20px; font-weight: bold;">
#     <span style="font-size: 22px;">👉</span> TF = একটি নির্দিষ্ট শব্দের সংখ্যা / বাক্যের মোট শব্দ সংখ্যা
#   </p>
# </div>
#
#
# suppose, **Sentence 1: "আমি ফুটবল ভালোবাসি"**
#
# | শব্দ  | সংখ্যা | TF গণনা | TF মান |
# |-------|-------|---------|--------|
# | আমি   | ১     | 1 / 3   | 0.33   |
# | ফুটবল | ১     | 1 / 3   | 0.33   |
# | ভালোবাসি | ১  | 1 / 3   | 0.33   |
#
# ---
#
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Step 2: Inverse Document Frequency (IDF) গণনা করা</h2>
#
#   <p style="text-align: center; font-size: 20px; font-weight: bold;">
#     <span style="font-size: 22px;">👉</span>IDF = log(বাক্যের সংখ্যা / নির্দিষ্ট শব্দটি যে কয়টি বাক্যে এসেছে)
#   </p>
# </div>
#
# আমাদের **৩টি বাক্য** আছে:
#
# | শব্দ  | কয়টি বাক্যে এসেছে | IDF গণনা | IDF মান |
# |-------|-------------------|----------|--------|
# | আমি   | ২                 | log(3/2) | 0.18   |
# | ফুটবল | ২                 | log(3/2) | 0.18   |
# | ভালোবাসি | ১              | log(3/1) | 0.48   |
#
# ---
#
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Step 3: TF-IDF মান নির্ধারণ করা</h2>
#
#   <p style="text-align: center; font-size: 20px; font-weight: bold;">
#     <span style="font-size: 22px;">👉</span>TF-IDF = TF × IDF
#   </p>
# </div>
#
#
# | শব্দ  | TF মান | IDF মান | TF-IDF গণনা | TF-IDF মান |
# |-------|--------|--------|-------------|------------|
# | আমি   | 0.33   | 0.18   | 0.33 × 0.18 | 0.06       |
# | ফুটবল | 0.33   | 0.18   | 0.33 × 0.18 | 0.06       |
# | ভালোবাসি | 0.33   | 0.48   | 0.33 × 0.48 | 0.16       |
#
# ---
#
# ## **🔹 গুরুত্বপূর্ণ পর্যবেক্ষণ**
# 📌 **"ভালোবাসি"** শব্দটির **TF-IDF মান বেশি**, কারণ এটি কমন নয় এবং **গুরুত্বপূর্ণ শব্দ**।
# 📌 সাধারণত, **যে শব্দ বেশি গুরুত্বপূর্ণ**, তার **TF-IDF মানও বেশি হয়**।
#
#
# ---
#
# ### **৬. One-Hot Encoding**
# - এটি একটি সহজ কৌশল, যেখানে প্রতিটি শব্দের জন্য একটি বিশাল ভেক্টর তৈরি করা হয়।
# - এই ভেক্টরের একটি মাত্র উপাদান ১ থাকে, যা সেই শব্দের অবস্থান নির্দেশ করে, এবং বাকি উপাদানগুলো ০ থাকে।
# - ওয়ান-হট এনকোডিং শব্দগুলোর মধ্যে সম্পর্ক প্রকাশ করতে পারে না, তাই এটি ওয়ার্ড এম্বেডিং এর তুলনায় কম কার্যকর।

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Text Representation</h2>
#
# ---
#
# ### **⭐ NLP-তে Text Representation বোঝার সহজ ব্যাখ্যা**
# - 🔹 **ব্যাগ অফ ওয়ার্ডস (Bag of Words - BoW)**
# - 🔹 **TF-IDF (Term Frequency - Inverse Document Frequency)**
# - 🔹 **N-Grams (Uni-grams, Bi-grams, Tri-grams ইত্যাদি)**
#
# ---
#
# ### **1️⃣ Bag of Words - (BoW)**
# **➡️ Explaination:**
# **Bag of Words (BoW)** হলো NLP-তে একটি সাধারণ টেক্সট রিপ্রেজেন্টেশন টেকনিক, যেখানে **একটি টেক্সটকে (Sentence/Document) পৃথক শব্দের Frequency বা গণনার ভিত্তিতে রিপ্রেজেন্ট করা হয়।** তবে **শব্দগুলোর ক্রম বা অর্থগত সম্পর্ক বিবেচনা করা হয় না।**
#
# ### **🔹 How does it work?**
# 1. প্রতিটি ইউনিক শব্দের একটি **ভোকাবুলারি (Vocabulary)** তৈরি করা হয়।
# 2. প্রতিটি ডকুমেন্টে ঐ শব্দগুলোর **কতবার ব্যবহৃত হয়েছে সেটি গণনা করা হয়।**
# 3. এই তথ্য ব্যবহার করে **একটি ভেক্টর (Vector) তৈরি করা হয়**, যা **মেশিন লার্নিং মডেল** ব্যবহার করতে পারে।
#
# #### **📌 Disadvantages of Bag of Words:**
# ❌ **শব্দগুলোর ক্রম বা কনটেক্সট বোঝে না।**
# ❌ **খুব বেশি শব্দ থাকলে স্পারসিটি (Sparsity) তৈরি হয়, অর্থাৎ ম্যাট্রিক্সটি অনেক বড় হয়ে যায়।**
#
# ---
#
# ### **2️⃣ TF-IDF (Term Frequency - Inverse Document Frequency)**
# **➡️ Explaination:**
# TF-IDF হলো **একটি উন্নত টেক্সট রিপ্রেজেন্টেশন পদ্ধতি**, যেখানে:
# - **কোনো শব্দ কতবার ব্যবহৃত হয়েছে (TF)** এবং
# - **সেটি কতগুলো ডকুমেন্টে পাওয়া গেছে (IDF)** এর উপর ভিত্তি করে **ওজন (Weight) নির্ধারণ করা হয়।**
#
# ### **🔹 How does it work?**
# - **Term Frequency (TF):**
#   - নির্দিষ্ট একটি শব্দের সংখ্যা / **মোট শব্দের সংখ্যা।**
# - **Inverse Document Frequency (IDF):**
#   - `log(মোট ডকুমেন্ট সংখ্যা / ঐ শব্দ যে ডকুমেন্টগুলোতে আছে তার সংখ্যা)`
#
# ### **📌 Example:**
# 💡 **যদি "Machine" শব্দটি দুইটি ডকুমেন্টেই থাকে**, তাহলে **IDF কম হবে**, কারণ এটি কম গুরুত্বপূর্ণ।
# 💡 **কিন্তু যদি "NLP" কেবল একটি ডকুমেন্টেই থাকে**, তাহলে **IDF বেশি হবে**, কারণ এটি বেশি গুরুত্বপূর্ণ।
#
# #### **⭐ TF-IDF ব্যবহারের সুবিধা:**
# ✅ এটি **গুরুত্বপূর্ণ শব্দগুলোর ওজন বেশি দেয়**, এবং কম গুরুত্বপূর্ণ শব্দগুলো (যেমন `"the", "is", "and"`) কম গুরুত্ব পায়।
# ✅ **স্প্যাম ডিটেকশন, ডকুমেন্ট ক্যাটাগরাইজেশন, এবং সার্চ ইঞ্জিন র‍্যাংকিং**-এ ব্যাপকভাবে ব্যবহৃত হয়।
#
# ---
#
# ✅ **এখন Markdown ফরম্যাটে পড়তে একদম সহজ হবে!** 🎯
# বলুন, আর কোনো পরিবর্তন লাগবে? 😊🚀
#
#
#
# ### 3️⃣ N-Grams (Uni-grams, Bi-grams, Tri-grams)
# ➡️ সহজ ব্যাখ্যা:
# N-Grams হলো একটি টেক্সটের টোকেন বা শব্দগুলোর ধারাবাহিক গ্রুপ তৈরি করার একটি পদ্ধতি, যা শব্দগুলোর ক্রম (Order) সংরক্ষণ করে।
#
# ### 🔹 কিভাবে কাজ করে?
# - Uni-gram: প্রতিটি শব্দ আলাদা আলাদা নেওয়া হয়।
# - Bi-gram: একসাথে দুইটি করে শব্দ নেওয়া হয়।
# - Tri-gram: একসাথে তিনটি করে শব্দ নেওয়া হয়।
#     - Sentence: "Natural Language Processing is amazing"
#     - Uni-gram: ["Natural", "Language", "Processing", "is", "amazing"]
#     - Bi-gram: ["Natural Language", "Language Processing", "Processing is", "is amazing"]
#     - Tri-gram: ["Natural Language Processing", "Language Processing is", "Processing is amazing"]
#
# ### ⭐ N-Grams-এর উপকারিতা:
# - ✅ এটি শব্দগুলোর ক্রম সংরক্ষণ করে।
# - ✅ স্প্যাম ডিটেকশন, টেক্সট জেনারেশন, মেশিন ট্রান্সলেশন, সিনট্যাকটিক অ্যানালাইসিস-এ ব্যবহৃত হয়।
# - ✅ Bi-gram এবং Tri-gram NLP-তে খুবই কার্যকরী কারণ এগুলো কনটেক্সট বুঝতে সাহায্য করে।
#
# #### 📌 challenge:
# - ❌ যদি টেক্সটে অনেক শব্দ থাকে, তাহলে N-Gram-ভিত্তিক ভেক্টর বড় হয়ে যেতে পারে (Dimensionality Issue)।
#
#
# ### ✅ Applications in Real Life.
# ```text
#     ✔ Spam Detection – TF-IDF ও BoW ব্যবহার করে ইমেইল স্প্যাম ডিটেকশন করা হয়।
#     ✔ Search Engine Optimization (SEO) – Google TF-IDF ও N-Gram ব্যবহার করে র‍্যাংকিং নির্ধারণ করে।
#     ✔ Chatbot Development – N-Grams ও TF-IDF ব্যবহার করে চ্যাটবটের টেক্সট প্রসেসিং উন্নত করা হয়।

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Difference between Text Representation & Word Representation</h2>
#
# ---
#
# # ![image.png](attachment:ef7d29e2-bbc7-4b37-9ed5-9968bcef7ec8.png)
