# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Terminologies</h2>
#
# ---
#
# - Corpus
# - Document
# - Feature
#
# ```
#
# This burger is very tasty and affordable
# This burger is not tasty and is affordable
# This burger is very very delicious
#
# 🔹 Corpus:
# কর্পাস বলতে সমস্ত ডকুমেন্টের সমষ্টিকে বোঝানো হয়। এখানে তিনটি বাক্য আছে, তাই এই তিনটি বাক্য একত্রে একটি কর্পাস তৈরি করে।
#
# 🔹 Document:
# A document is a single text data point. For Example, a review of a particular product by the user.
# অর্থাৎ কার্পাসের প্রত্যেকটা টেক্সটকে বলা হয় ডকুমেন্ট! Number of Documents এখানে ৩টি ডকুমেন্ট রয়েছে
#
# 🔹 Number of Features:
# ফিচার বলতে সমস্ত unique words বোঝানো হয়, যা কর্পাস থেকে পাওয়া যায়।
# প্রতিটি বাক্যের অনন্য শব্দগুলো হবে:
# ['This', 'burger', 'is', 'very', 'tasty', 'and', 'affordable', 'not', 'delicious']
#
# এখানে 9টি অনন্য শব্দ features রয়েছে।
# কর্পাস = ১টি
# ডকুমেন্ট = ৩টি
# ফিচার = ৯টি

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Word Embedding</h2>
#
# ---
# ```
# What is Word Embedding?
# মেশিন লার্নিং মডেল সরাসরি টেক্সট বা ইমেজ ইনপুট হিসেবে নিতে পারে না, কারণ এটি সেগুলো বোঝে না। যখন টেক্সট বা ইমেজকে সংখ্যায় রূপান্তর করা হয়, তখন মডেল সহজেই ইনপুটটি বুঝতে পারে এবং বিশ্লেষণ করতে সক্ষম হয়। টেক্সট বা ইমেজকে সংখ্যায় রূপান্তর করার এই প্রক্রিয়াকেই Word Embedding বলা হয়।
#
# In very simple terms, Word Embeddings are the texts converted into numbers, and there may be different numerical representations of the same text. But before we dive into the details of Word Embeddings, the following question should come to mind:
#
# সহজ ভাষায়, Word Embedding হলো যেকোনো টেক্সটকে numbers convert করাকে বলা হয় Word Embedding।
# একই পাঠ্যের একাধিক সংখ্যাগত উপস্থাপনাও থাকতে পারে।

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Count Vectorizer</h2>
#
# ---
# - **একটা perticular words একটা ডকুমেন্টে কতবার আছে তাকে কাউন্ট ভেক্টরাইজেশন বলে**
#
# **Matrix Formulation**:
# Count Vectorizer converts a corpus of documents into a matrix, where:
#
# **Rows represent documents**.
# Columns represent unique words (tokens) in the corpus.
# Each cell shows how many times a word appears in a specific document.
#
# Example:
# **Documents**:
# He is a smart boy. She is also smart.
# Chirag is a smart person.
# Unique Words: ['He', 'She', 'smart', 'boy', 'Chirag', 'person']
#
# Count Matrix:
#
# # ![image.png](attachment:a873cf53-6057-43c3-8ade-121ec8947fec.png)

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Bag-of-Words (BoW)</h2>
#
# ---
#
# In the Bag-of-Words (BoW) approach of text vectorization, we perform two main operations:
# - Tokenization:
# - Vectors Creation:
#
# 🔹 Tokenization:
# এটি একটি বাক্যকে ছোট ছোট শব্দ বা অংশে বিভক্ত করার প্রক্রিয়া, যা টোকেন (Token) নামে পরিচিত। টোকেনাইজেশনের পরে, আমরা কর্পাস থেকে সমস্ত অনন্য শব্দ বের করি। এখানে কর্পাস বলতে সমস্ত ডকুমেন্ট থেকে প্রাপ্ত টোকেনের সমষ্টিকে বোঝানো হয়, যা Bag-of-Words তৈরির জন্য ব্যবহৃত হয়।
#
# 🔹 Vectors Creation:
# টোকেনাইজেশনের পর, প্রতিটি ডকুমেন্টকে একটি ভেক্টরে রূপান্তর করা হয়, যেখানে কর্পাসের প্রতিটি অনন্য শব্দ একটি ফিচার (Feature) হিসাবে কাজ করে, এবং সেই শব্দটি ডকুমেন্টে কতবার এসেছে, সেটি সংখ্যা হিসেবে সংরক্ষিত হয়।

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">N-grams Vectorization</h2>
#
# ---
# ```
# N-grams
# 🔹 N-gram পদ্ধতির মাধ্যমে number of combination, number of sequence, number of features জেনারেট করতে পারি। এটি text data কে আরো smoothly analysis করতে সক্ষম করে।
# অর্থাৎ আমি আমার NLP Model কে বিভিন্ন অ্যাঙ্গেল থেকে different word sequences এর মাধ্যমে train করাতে পারতেছি। এই concept টা কে N-grams বলে।
#
# 🔹 N-grams একটা sentence কে নাম্বার অফ N-grams এর উপর ডিপেন্ড করে Bigram হবে নাকি Trigrams হবে নাকি Four-grams হবে এটার উপর depend করে সে অনেকগুলো sequence of words জেনারেট করে দিচ্ছে যেটা এনএলপি মডেলের নাম্বার of features হিসেবে কাজ করবে।
#
# Example:
# Sentence: "This burger is very tasty"
# 🔹 1-Gram: ['This', 'burger', 'is', 'very', 'tasty']
# 🔹 2-Gram (Bigram): ['This burger', 'burger is', 'is very', 'very tasty']
# 🔹 3-Gram (Trigram): ['This burger is', 'burger is very', 'is very tasty']
# 🔹 4-Four-gram: ['This burger is very', 'burger is very tasty']
#
# N-grams Vectorization
# 🔹 Similar to the count vectorization technique, in the N-Gram method, a document term matrix is generated, and each cell represents the count.
# 🔹 The columns represent all columns of adjacent words of length n.
# 🔹 Count vectorization is a special case of N-Gram where n = 1.
# 🔹 N-grams consider the sequence of n words in the text, where n is (1, 2, 3…). Like 1-gram, 2-gram for token pair. Unlike BoW, it maintains word order.

# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">TF-IDF Vectorizer</h2>
#
# ---
#
# - TF: যেকোনো ডকুমেন্টে Total কয়টা unique words আছে এবং total words কয়টা আছে তার অনুপাতকে TF বলে
#
# ## 1. Term Frequency (TF):
#
# TF: একটি ডকুমেন্টে একটি Unique word কতবার এসেছে, তার পরিমাপ।. The formula is:
#
# $$
# TF = \frac{\text{Number of times the word appears in the document}}{\text{Total number of words in the document}}
# $$
#
# - Document-01: "I love Natural Language Processing"
# - Document-02: "I love computer vision"
#
# - মোট শব্দ সংখ্যা: 5টি ['I', 'love', 'Natural', 'Language', 'Processing']
# # ![image.png](attachment:81438862-2be1-4fde-bf81-afa763a08cfb.png)
# Document-01 এর প্রতিটি শব্দের TF = 0.2, কারণ সব শব্দ ১ বার এসেছে এবং মোট ৫টি শব্দ রয়েছে।
#
# ---
#
# ## 2. Inverse Document Frequency (IDF):
#
# - IDF: সেই শব্দটি কতগুলো ডকুমেন্টে পাওয়া যায়, তার পরিমাপ।. The formula is:
# - Total Documents:2
#
# $$
# IDF = \log\left(\frac{\text{Total number of documents}}{\text{Number of documents containing the word}}\right)
# $$
#
# # ![image.png](attachment:3635e96c-e631-42f6-befc-196be345734f.png)
#
# - Common words (I, love) দুই ডকুমেন্টেই আছে, তাই তাদের IDF = 0.0।
# - Unique words (Natural, Language, Processing) কেবল Document-01 এ আছে, তাই তাদের IDF = 0.693।
# ---
#
# ## Final Formula:
# অর্থাৎ একটা ডকুমেন্টে TF এবং IDF এর গুণফল কে TF-IDF বলে।
# $$
# TF - IDF = TF \times IDF
# $$
#
# # ![image.png](attachment:a87c45d4-19ea-442f-9ec6-d6a3484383df.png)
# - Common words (I, love) এর TF-IDF = 0.0, কারণ তারা দুই ডকুমেন্টেই রয়েছে।
# - Unique words (Natural, Language, Processing) এর TF-IDF = 0.1386, কারণ তারা শুধুমাত্র Document-01 এ রয়েছে।
# ---
#
# ## **Why is it important?**
# - It highlights important words in a document while reducing the impact of commonly used words.
# - Helps in improving the performance of text-based machine learning models.
