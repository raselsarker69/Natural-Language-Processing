# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">Grammatical rules Checking</h2>
#
# ---
#
#
# 🔍 **1. Sentence Structure (Syntax Checking)**
# - The structure of a sentence (how words are arranged) is crucial for correctness. We check:
#
# - Subject-Verb Agreement:
#     - Example (Correct): সে বই পড়ছে।
#     - Example (Incorrect): সে বই পড়ছে না আছো।
# - Word Order: Proper arrangement of subject, verb, and object (SVO structure in Bangla).
#     - Example (Correct): আমি ভাত খাই।
#     - Example (Incorrect): খাই আমি ভাত।
# - Phrase and Clause Structure: Ensure proper subordination and coordination of clauses.
#     - Example (Correct): যদি তুমি আসো, আমি যাব।
#     - Example (Incorrect): যদি তুমি আসো আমি যাব।
#
# ✏️ **2. Parts of Speech (POS Tagging)**
# - Each word in a sentence plays a grammatical role. We check:
#
# - Noun: Proper use of subjects and objects.
# - Verb: Correct tense, aspect, and mood.
# - Adjective: Proper word form for description.
# - Adverb: Correctly modifying verbs or adjectives.
# - Preposition: Proper connection between words.
# - Conjunction: Proper linking of clauses or phrases.
# - Example:
#     - Correct: সে দ্রুত হাঁটছে। (Adverb "দ্রুত" correctly modifies the verb "হাঁটছে")
#     - Incorrect: সে দ্রুত বই পড়ছে। ("দ্রুত" is used wrongly here for reading)
#
# 📖 **3. Tense, Aspect, and Mood (TAM)**
# - Tense refers to time, aspect shows the continuity or completion, and mood reflects intent.
#
# - Tense: Present, Past, Future
# - Aspect: Simple, Continuous, Perfect
# - Mood: Indicative, Imperative, Subjunctive
# - Example:
#     - Correct: সে স্কুলে যায়। (Present Simple)
#     - Incorrect: সে স্কুলে যাই। (Wrong verb form for present tense)
#
# 📝 **4. Subject-Verb Agreement (Concord Checking)**
# - The verb must agree with the subject in number and person.
#
# - Singular subject → Singular verb
# - Plural subject → Plural verb
# - Example:
#     - Correct: আমি বই পড়ছি।
#     - Incorrect: আমি বই পড়ছে।
#
# 📏 **5. Word Form and Inflection (Morphology)**
# - We check if words are correctly inflected for tense, case, gender, or number.
#
# Example (Noun Form):
# - Correct: শিক্ষকরা ক্লাস নিচ্ছেন। (Plural form with proper verb agreement)
# - Incorrect: শিক্ষক ক্লাস নিচ্ছেন। (If plural is intended)
# - Example (Verb Form):
#     - Correct: সে লিখছে।
#     - Incorrect: সে লিখতেছে।
# -
# 🪶 **6. Punctuation and Capitalization**
# - Proper punctuation ensures clarity. We check:
#
# - Period (।) at the end of a sentence.
# - Comma (,) for listing items.
# - Question Mark (?) for questions.
# - Exclamation Mark (!) for emphasis.
# - Example:
#     - Correct: তুমি কোথায় যাচ্ছ?
#     - Incorrect: তুমি কোথায় যাচ্ছ (Missing question mark)
#
# 📚 **7. Semantic Consistency (Meaningful Sentence)**
# - Even if a sentence is grammatically correct, it must make logical sense.
#
# Example:
# - Correct Grammar but Nonsensical: বইটি পানি খায়। (Grammatically fine, but semantically incorrect.)
# - Correct and Logical: বইটি টেবিলে আছে।
#
# 🌿 **8. Pronoun Usage and Reference (Anaphora Resolution)**
# - Pronouns must clearly refer to their antecedents.
#
# - Correct: রাহুল বলল যে সে আসবে। (The pronoun সে refers to রাহুল)
# - Incorrect: রাহুল বলল যে তারা আসবে। (Who are তারা referring to?)
#
# 🔤 **9. Spelling and Word Formation (Orthography)**
# - Spelling mistakes can change meaning or make a sentence invalid.
#
# - Correct: আমি বাংলা ভালোবাসি।
# - Incorrect: আমি ভাঙ্গলা ভালোবাসি।
#
# ✨ **10. Idiomatic and Stylistic Correctness**
# - Even if a sentence follows grammar, idiomatic expressions should sound natural.
#
# - Correct: সে পরীক্ষায় পাশ করেছে।
# - Incorrect: সে পরীক্ষায় লাফিয়েছে।
