# %% [markdown]
# <div style="background-color: #f9f9fc; color: #333366; border-radius: 12px; margin: 20px auto; padding: 20px; border: 2px solid #ff4c4c; max-width: 1000px; font-family: Arial, sans-serif; line-height: 1.6;">
#   <h2 style="text-align: center; color: #333366;">📌 spaCy</h2>
#
# ---
#
# ## 📝 **Introduction**
# **spaCy** হলো **Natural Language Processing (NLP)**-এর জন্য একটি **দ্রুত, দক্ষ ও শক্তিশালী পাইথন লাইব্রেরি**।
# এটি মূলত **Industrial-Grade NLP** বা **প্রোডাকশন-লেভেল টেক্সট প্রসেসিং** এর জন্য তৈরি করা হয়েছে।
# spaCy অনেক NLP কাজ **অপ্টিমাইজড Cython কোডে** করে, ফলে এটি অন্যান্য NLP লাইব্রেরির তুলনায় অনেক দ্রুত কাজ করে।
#
# ---
#
# ## 🔍 **spaCy-এর প্রধান বৈশিষ্ট্যসমূহ**
# ✅ **Fast & Efficient** → অন্যান্য NLP লাইব্রেরির তুলনায় দ্রুত কাজ করে
# ✅ **Pre-trained Pipelines** → বিভিন্ন ভাষার জন্য **প্রশিক্ষিত (pre-trained) মডেল**
# ✅ **Tokenization** → দ্রুত এবং নির্ভুল **টোকেনাইজেশন**
# ✅ **Part-of-Speech (POS) Tagging** → প্রতিটি শব্দের **ব্যাকরণগত ক্যাটাগরি চিহ্নিত করা**
# ✅ **Named Entity Recognition (NER)** → **টেক্সট থেকে নাম, স্থান, সংস্থা ইত্যাদি শনাক্ত করা**
# ✅ **Dependency Parsing** → **শব্দের সম্পর্ক (syntactic dependencies) বিশ্লেষণ**
# ✅ **Lemmatization** → **শব্দের মূল রূপ খুঁজে বের করা**
# ✅ **Multi-language Support** → **একাধিক ভাষার সমর্থন**
# ✅ **Deep Learning Integration** → **Transformers, BERT, এবং অন্যান্য DL মডেল সমর্থন**
#
# ---
#
# ## 📌 **spaCy কী কী কাজে ব্যবহার করা হয়?**
# spaCy অনেক ধরনের **NLP (Natural Language Processing) টাস্ক**-এ ব্যবহৃত হয়।
# নিচে **Step-by-Step** বিভিন্ন প্রয়োগ দেওয়া হলো:
#
# ---
#
# ### **1️⃣ Text Tokenization**
# spaCy **Word Tokenization** এ বিভক্ত করতে পারে।
#
#
# ### 2️⃣ Part-of-Speech (POS) Tagging
# - Noun, Verb, Adjective ইত্যাদি শনাক্ত করতে পারে
#
# ### 3️⃣ Named Entity Recognition (NER)
# - spaCy টেক্সট থেকে গুরুত্বপূর্ণ তথ্য বের করে, যেমন নাম, স্থান, সংস্থা ইত্যাদি।
#         doc = nlp("Apple is looking at buying a startup in New York for $1 billion.")
#         for ent in doc.ents:
#             print(ent.text, " --> ", ent.label_)
#
# ### 4️⃣ Dependency Parsing (শব্দের সম্পর্ক নির্ধারণ)
# - spaCy একটি বাক্যে শব্দগুলোর সম্পর্ক বের করতে পারে।
# for token in doc:
#     print(token.text, "-->", token.dep_, "-->", token.head.text)
#
# ### 5️⃣ Lemmatization (শব্দের মূল রূপ নির্ধারণ)
# - spaCy শব্দগুলোর মূল রূপ (Lemma) বের করতে পারে।
#
# ### 📌 spaCy-এর Advantages
# - ✅ অত্যন্ত দ্রুত এবং ইফিশিয়েন্ট (Fast & Efficient)
# - ✅ প্রোডাকশন রেডি (Production-Ready)
# - ✅ প্রাক-প্রশিক্ষিত মডেল (Pretrained Models) সমর্থন করে
# - ✅ NER, POS Tagging, Dependency Parsing, Lemmatization ইত্যাদির জন্য শক্তিশালী টুলস
# - ✅ Multi-language সমর্থন করে
# - ✅ Deep Learning ও Transformers এর সাথে সহজেই ইন্টিগ্রেট করা যায়

# %% [markdown]
# ### spaCy vs. other NLP libraries.

# %% [markdown]
# # ![image.png](attachment:dafec100-f20f-4018-b327-3890aecaf741.png)

# %% [markdown]
# ### 🎯 Summary
# spaCy হলো সর্বাধিক শক্তিশালী ও দ্রুতগামী NLP লাইব্রেরি, যা Tokenization, POS Tagging, Named Entity Recognition (NER), Dependency Parsing, Lemmatization, এবং Machine Learning মডেলের জন্য উপযোগী।
# এটি প্রোডাকশন লেভেলের NLP প্রজেক্ট এর জন্য পারফেক্ট এবং Deep Learning মডেলের সাথেও সহজে ইন্টিগ্রেট করা যায়।
